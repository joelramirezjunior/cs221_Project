# %%
import mido
import os
import glob
import pickle
from mido import MidiFile, MidiTrack, Message
from tensorflow.keras.layers import LSTM, Dense, Activation, Dropout, Flatten
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from tensorflow.keras import optimizers
from random import randint 
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
def grabName(key):
    x = key.split('/')
    y = x[1]
    z = y.split('.')
    return z[0]

# %%
def geMidiFileAndTest():
    allMidiFile = 'clean_midi_songs/*.mid'
    return allMidiFile

# %%
def getNotes(allMidiFile):
        training_notes = []
        prediction_notes = dict()
        
        #getting all the notes we are training model on TO MAKE prediction
        for file in glob.glob(allMidiFile):
            individualSong = []
            midi= MidiFile(file)
            print('Loading file: ', file)
            for msg in midi:
                if not msg.is_meta and msg.type == 'note_on':
                    data = msg.bytes()
                    individualSong.append(data[1])
            # we store these to make predictions based on different songs
            prediction_notes[file] = individualSong
            # these we use to train. Stored as individual list so that the songs are 
            # not overlaped in training
            training_notes.append(individualSong)
    
        return training_notes, prediction_notes

# %%
# subsample data for training and prediction
def prepareSequences(n_prev, training_notes):

    sequences = []
    y = []

    #here we are iterating through different songs
    # this assures that none of the sequences have different songs
    for training_note in training_notes:
        for i in range(len(training_note)-n_prev):
            sequences.append(training_note[i:i+n_prev])
            y.append(training_note[i+n_prev])
    
    # save a seed to do prediction later
    # this will grab all elements up to the 301st to last
    sequence_test = sequences[-300:]
    sequences = np.asarray(sequences[:-300])
    y = y[:-300]

    return sequences, sequence_test, y

# %%
def encondeClassValues(y):
    # encode class values as integers
    encoder = LabelEncoder()
    encoder.fit(y)
    encoded_Y = encoder.transform(y)

    # convert integers to dummy variables (i.e. one hot encoded ;-) 
    dummy_y = np_utils.to_categorical(encoded_Y)
    return encoder, encoded_Y, dummy_y

# %%
# define baseline model
def baseline_model(dummy_y, n_prev):
    # create model
    model = Sequential()

    # put in this Dense 128, but it could be easily removed.
    model.add(Dense(128, input_dim=n_prev, activation='relu'))
    model.add(Dense(64, input_dim=n_prev, activation='relu'))
    model.add(Dense(len(dummy_y[0]), activation='softmax'))

    # Compile model
    # Here we use a really small learning rate becuase a larger one will not converge at all
    sgd = optimizers.SGD(lr=0.00001, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    return model

# %%
def runModel(dummy_y, sequences, nprev, numIteration ):
    model = baseline_model(dummy_y, nprev)
    model.fit(sequences, dummy_y, 32, numIteration, verbose=1)
    return model

# %%
def makePrediction(y, prediction_notes, n_prev, model):

    # these are the names for the respective file names which we created in getNotes (line 31)
    all_keys = prediction_notes.keys()

    # These are dicts inorder to predict based on different songs. This helps so that you don't 
    # have to change every single 'predicted' song in code every time. Will iterate through all.
    predictions = dict()
    class_labels = dict()
    class_labels_min = dict()
    final_labels = dict()

    # here we iterate through all songs
    for key in all_keys:
        sequenced_test_notes = []
        #differnce prediction based on different song (i.e. key)
        sequence = prediction_notes[key]
        for i in range(len(sequence)-n_prev):
            sequenced_test_notes.append(sequence[i:i+n_prev])

        # results based on song
        prediction = model.predict(np.array(sequenced_test_notes))
        class_label = np.argmax(prediction, axis=1)
        class_label_min = np.argmin(prediction, axis=1)
        labels = list(set(y))
        final_label = [labels[i] for i in class_label]
        final_labels[key] = final_label

        # saving to dictionaries
        predictions[key] = prediction
        final_labels[key] = final_label
        class_labels[key] = class_label
        class_labels_min[key] = class_label_min

    return predictions, class_labels, class_labels_min, final_labels, all_keys

# %%
def createPredictedSong(final_labels, key):
    
    mid = MidiFile()
    track = MidiTrack()
    # there is some way to moderate this to make notes less clutterd. Need To Fix.
    t = 0
    for note in final_labels[key]:
        # 147 means note_on
        # 67 is velosity
        singleNote = np.asarray([147, note, 67])
        bytes = singleNote.astype(int)
        msg = Message.from_bytes(bytes[0:3])
        t += 1 
        msg.time = t
        track.append(msg)
    # created this function to make this more legible
    key = grabName(key)
    mid.tracks.append(track)
    mid.save('created/allTrainedwith-%s-asPredicted.mid' %key)

# %%
def createSongUsedToPredict(prediction_notes, key):
    #exact same as above function, only used for predictors
    test_mid = MidiFile()
    test_track = MidiTrack()
    t = 0
    overlap = 0
    for note in prediction_notes[key]:
        # 147 means note_on
        # 67 is velosity
        note = np.asarray([147, note, 67])
        bytes = note.astype(int)
        msg = Message.from_bytes(bytes[0:3])
        t += 1 
        overlap+=1
        msg.time = t
        test_track.append(msg)
    test_mid.tracks.append(test_track)
    key = grabName(key)
    test_mid.save('predicted/predicted_song_%s.mid' %key)

# %%
# here are all the function calls
# what do you want the sequence length to be?
nprev = 4

# how many iterations do you want?
numIteration = 200

allMidiFile = geMidiFileAndTest()
training_notes, prediction_notes = getNotes(allMidiFile)
sequences, sequence_test, y = prepareSequences(nprev, training_notes)
encoder, encoded_Y, dummy_y = encondeClassValues(y)
model = runModel(dummy_y, sequences, nprev, numIteration)
predictions, class_labels, class_labels_min, final_labels, keys = makePrediction(y, prediction_notes, nprev, model)
for key in keys:
    createPredictedSong(final_labels, key)
    createSongUsedToPredict(prediction_notes, key)
# Out:
# Loading file:  clean_midi_songs/jinetera.mid
# Loading file:  clean_midi_songs/rumberaWchirino.mid
# Loading file:  clean_midi_songs/salsaPiano.mid
# Loading file:  clean_midi_songs/mujerdearenaodeloeon.mid
# Loading file:  clean_midi_songs/oPaoSalsa.mid
# Loading file:  clean_midi_songs/ahoraquien.mid
# Loading file:  clean_midi_songs/asifue.mid
# Loading file:  clean_midi_songs/lloraras.mid
# Loading file:  clean_midi_songs/MITIERRA[1].mid
# Loading file:  clean_midi_songs/abusowillieCol.mid
# Loading file:  clean_midi_songs/devorame.mid
# Loading file:  clean_midi_songs/Bamboleo.mid
# Train on 39202 samples
# Epoch 1/200
# 39202/39202 [==============================] - 2s 51us/sample - loss: 5.0621 - accuracy: 0.0449
# Epoch 2/200
# 39202/39202 [==============================] - 1s 38us/sample - loss: 3.6113 - accuracy: 0.0536
# Epoch 3/200
# 39202/39202 [==============================] - 1s 38us/sample - loss: 3.5574 - accuracy: 0.0577
# Epoch 4/200
# 39202/39202 [==============================] - 2s 60us/sample - loss: 3.5334 - accuracy: 0.0593
# Epoch 5/200
# 39202/39202 [==============================] - 2s 58us/sample - loss: 3.5199 - accuracy: 0.0622
# Epoch 6/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.5104 - accuracy: 0.0644
# Epoch 7/200
# 39202/39202 [==============================] - 2s 47us/sample - loss: 3.5033 - accuracy: 0.0669
# Epoch 8/200
# 39202/39202 [==============================] - 2s 49us/sample - loss: 3.4964 - accuracy: 0.0700
# Epoch 9/200
# 39202/39202 [==============================] - 2s 44us/sample - loss: 3.4919 - accuracy: 0.0699
# Epoch 10/200
# 39202/39202 [==============================] - 2s 51us/sample - loss: 3.4885 - accuracy: 0.0720
# Epoch 11/200
# 39202/39202 [==============================] - 2s 43us/sample - loss: 3.4862 - accuracy: 0.0708
# Epoch 12/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.4828 - accuracy: 0.0697
# Epoch 13/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4803 - accuracy: 0.0691
# Epoch 14/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4781 - accuracy: 0.0723
# Epoch 15/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4758 - accuracy: 0.0719
# Epoch 16/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.4744 - accuracy: 0.0719
# Epoch 17/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4723 - accuracy: 0.0719
# Epoch 18/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.4705 - accuracy: 0.0720
# Epoch 19/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4699 - accuracy: 0.0726
# Epoch 20/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4689 - accuracy: 0.0728
# Epoch 21/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4668 - accuracy: 0.0740
# Epoch 22/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4661 - accuracy: 0.0736
# Epoch 23/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.4650 - accuracy: 0.0747
# Epoch 24/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4635 - accuracy: 0.0737
# Epoch 25/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4627 - accuracy: 0.0722
# Epoch 26/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4620 - accuracy: 0.0739
# Epoch 27/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4608 - accuracy: 0.0753
# Epoch 28/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4598 - accuracy: 0.0743
# Epoch 29/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4594 - accuracy: 0.0739
# Epoch 30/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4580 - accuracy: 0.0763
# Epoch 31/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.4577 - accuracy: 0.0743
# Epoch 32/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4565 - accuracy: 0.0739
# Epoch 33/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.4564 - accuracy: 0.0757
# Epoch 34/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.4549 - accuracy: 0.0759
# Epoch 35/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.4539 - accuracy: 0.0768
# Epoch 36/200
# 39202/39202 [==============================] - 2s 44us/sample - loss: 3.4531 - accuracy: 0.0756
# Epoch 37/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4521 - accuracy: 0.0779
# Epoch 38/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.4514 - accuracy: 0.0782
# Epoch 39/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.4505 - accuracy: 0.0778
# Epoch 40/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4496 - accuracy: 0.0792
# Epoch 41/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.4487 - accuracy: 0.0771
# Epoch 42/200
# 39202/39202 [==============================] - 1s 38us/sample - loss: 3.4490 - accuracy: 0.0783
# Epoch 43/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.4479 - accuracy: 0.0758
# Epoch 44/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.4466 - accuracy: 0.0779
# Epoch 45/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.4460 - accuracy: 0.0779
# Epoch 46/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.4456 - accuracy: 0.0769
# Epoch 47/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.4447 - accuracy: 0.0781
# Epoch 48/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4446 - accuracy: 0.0780
# Epoch 49/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4445 - accuracy: 0.0786
# Epoch 50/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4437 - accuracy: 0.0777
# Epoch 51/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.4433 - accuracy: 0.0767
# Epoch 52/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4433 - accuracy: 0.0794
# Epoch 53/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4419 - accuracy: 0.0778
# Epoch 54/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4413 - accuracy: 0.0776
# Epoch 55/200
# 39202/39202 [==============================] - 2s 38us/sample - loss: 3.4412 - accuracy: 0.0775
# Epoch 56/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.4406 - accuracy: 0.0793
# Epoch 57/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.4404 - accuracy: 0.0774
# Epoch 58/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.4394 - accuracy: 0.0777
# Epoch 59/200
# 39202/39202 [==============================] - 2s 43us/sample - loss: 3.4395 - accuracy: 0.0772
# Epoch 60/200
# 39202/39202 [==============================] - 1s 38us/sample - loss: 3.4389 - accuracy: 0.0792
# Epoch 61/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.4375 - accuracy: 0.0789
# Epoch 62/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.4384 - accuracy: 0.0782
# Epoch 63/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.4371 - accuracy: 0.0788
# Epoch 64/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.4378 - accuracy: 0.0794
# Epoch 65/200
# 39202/39202 [==============================] - 2s 40us/sample - loss: 3.4367 - accuracy: 0.0781
# Epoch 66/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.4360 - accuracy: 0.0798
# Epoch 67/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.4355 - accuracy: 0.0805
# Epoch 68/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4354 - accuracy: 0.0800
# Epoch 69/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4353 - accuracy: 0.0788
# Epoch 70/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4351 - accuracy: 0.0792
# Epoch 71/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4341 - accuracy: 0.0792
# Epoch 72/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4337 - accuracy: 0.0800
# Epoch 73/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4332 - accuracy: 0.0779
# Epoch 74/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4325 - accuracy: 0.0791
# Epoch 75/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4323 - accuracy: 0.0795
# Epoch 76/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4323 - accuracy: 0.0825
# Epoch 77/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4317 - accuracy: 0.0813
# Epoch 78/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4322 - accuracy: 0.0802
# Epoch 79/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4316 - accuracy: 0.0818
# Epoch 80/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4309 - accuracy: 0.0807
# Epoch 81/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.4306 - accuracy: 0.0806
# Epoch 82/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4309 - accuracy: 0.0780
# Epoch 83/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4299 - accuracy: 0.0796
# Epoch 84/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4296 - accuracy: 0.0802
# Epoch 85/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4297 - accuracy: 0.0776
# Epoch 86/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4282 - accuracy: 0.0805
# Epoch 87/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4288 - accuracy: 0.0790
# Epoch 88/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4284 - accuracy: 0.0795
# Epoch 89/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4270 - accuracy: 0.0807
# Epoch 90/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4271 - accuracy: 0.0811
# Epoch 91/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4268 - accuracy: 0.0808
# Epoch 92/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4272 - accuracy: 0.0794
# Epoch 93/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4253 - accuracy: 0.0797
# Epoch 94/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4256 - accuracy: 0.0807
# Epoch 95/200
# 39202/39202 [==============================] - 2s 48us/sample - loss: 3.4255 - accuracy: 0.0803
# Epoch 96/200
# 39202/39202 [==============================] - 2s 47us/sample - loss: 3.4247 - accuracy: 0.0815
# Epoch 97/200
# 39202/39202 [==============================] - 2s 40us/sample - loss: 3.4248 - accuracy: 0.0787
# Epoch 98/200
# 39202/39202 [==============================] - 2s 40us/sample - loss: 3.4247 - accuracy: 0.0809
# Epoch 99/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.4240 - accuracy: 0.0807
# Epoch 100/200
# 39202/39202 [==============================] - 2s 49us/sample - loss: 3.4244 - accuracy: 0.0804
# Epoch 101/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.4227 - accuracy: 0.0818
# Epoch 102/200
# 39202/39202 [==============================] - 2s 43us/sample - loss: 3.4230 - accuracy: 0.0809
# Epoch 103/200
# 39202/39202 [==============================] - 2s 43us/sample - loss: 3.4224 - accuracy: 0.0807
# Epoch 104/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.4223 - accuracy: 0.0810
# Epoch 105/200
# 39202/39202 [==============================] - 2s 52us/sample - loss: 3.4218 - accuracy: 0.0812
# Epoch 106/200
# 39202/39202 [==============================] - 2s 48us/sample - loss: 3.4209 - accuracy: 0.0806
# Epoch 107/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4209 - accuracy: 0.0834
# Epoch 108/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4214 - accuracy: 0.0815
# Epoch 109/200
# 39202/39202 [==============================] - 2s 40us/sample - loss: 3.4203 - accuracy: 0.0802
# Epoch 110/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4199 - accuracy: 0.0819
# Epoch 111/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4196 - accuracy: 0.0826
# Epoch 112/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4192 - accuracy: 0.0798
# Epoch 113/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4194 - accuracy: 0.0819
# Epoch 114/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4183 - accuracy: 0.0808
# Epoch 115/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4182 - accuracy: 0.0817
# Epoch 116/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4179 - accuracy: 0.0835
# Epoch 117/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4173 - accuracy: 0.0825
# Epoch 118/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4168 - accuracy: 0.0834
# Epoch 119/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4171 - accuracy: 0.0820
# Epoch 120/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4167 - accuracy: 0.0812
# Epoch 121/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.4162 - accuracy: 0.0824
# Epoch 122/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4156 - accuracy: 0.0821
# Epoch 123/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.4156 - accuracy: 0.0819
# Epoch 124/200
# 39202/39202 [==============================] - 3s 79us/sample - loss: 3.4153 - accuracy: 0.0821
# Epoch 125/200
# 39202/39202 [==============================] - 2s 59us/sample - loss: 3.4146 - accuracy: 0.0814
# Epoch 126/200
# 39202/39202 [==============================] - 2s 51us/sample - loss: 3.4145 - accuracy: 0.0819
# Epoch 127/200
# 39202/39202 [==============================] - 2s 47us/sample - loss: 3.4139 - accuracy: 0.0826
# Epoch 128/200
# 39202/39202 [==============================] - 2s 56us/sample - loss: 3.4139 - accuracy: 0.0810
# Epoch 129/200
# 39202/39202 [==============================] - 2s 50us/sample - loss: 3.4135 - accuracy: 0.0813
# Epoch 130/200
# 39202/39202 [==============================] - 3s 84us/sample - loss: 3.4135 - accuracy: 0.0816
# Epoch 131/200
# 39202/39202 [==============================] - 2s 60us/sample - loss: 3.4124 - accuracy: 0.0826
# Epoch 132/200
# 39202/39202 [==============================] - 2s 54us/sample - loss: 3.4131 - accuracy: 0.0824
# Epoch 133/200
# 39202/39202 [==============================] - 2s 39us/sample - loss: 3.4116 - accuracy: 0.0831
# Epoch 134/200
# 39202/39202 [==============================] - 2s 40us/sample - loss: 3.4118 - accuracy: 0.0812
# Epoch 135/200
# 39202/39202 [==============================] - 2s 48us/sample - loss: 3.4117 - accuracy: 0.0832
# Epoch 136/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.4114 - accuracy: 0.0839
# Epoch 137/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.4111 - accuracy: 0.0813
# Epoch 138/200
# 39202/39202 [==============================] - 2s 43us/sample - loss: 3.4106 - accuracy: 0.0817
# Epoch 139/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4102 - accuracy: 0.0836
# Epoch 140/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4098 - accuracy: 0.0827
# Epoch 141/200
# 39202/39202 [==============================] - 1s 38us/sample - loss: 3.4097 - accuracy: 0.0832
# Epoch 142/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.4095 - accuracy: 0.0834
# Epoch 143/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4087 - accuracy: 0.0829
# Epoch 144/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.4093 - accuracy: 0.0833
# Epoch 145/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.4085 - accuracy: 0.0845
# Epoch 146/200
# 39202/39202 [==============================] - 2s 46us/sample - loss: 3.4074 - accuracy: 0.0841
# Epoch 147/200
# 39202/39202 [==============================] - 2s 54us/sample - loss: 3.4080 - accuracy: 0.0813
# Epoch 148/200
# 39202/39202 [==============================] - 2s 44us/sample - loss: 3.4075 - accuracy: 0.0833
# Epoch 149/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4083 - accuracy: 0.0830
# Epoch 150/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.4074 - accuracy: 0.0849
# Epoch 151/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.4076 - accuracy: 0.0837
# Epoch 152/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.4068 - accuracy: 0.0820
# Epoch 153/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4062 - accuracy: 0.0836
# Epoch 154/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4059 - accuracy: 0.0835
# Epoch 155/200
# 39202/39202 [==============================] - 2s 39us/sample - loss: 3.4056 - accuracy: 0.0828
# Epoch 156/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.4051 - accuracy: 0.0843
# Epoch 157/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.4051 - accuracy: 0.0810
# Epoch 158/200
# 39202/39202 [==============================] - 2s 48us/sample - loss: 3.4052 - accuracy: 0.0834
# Epoch 159/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.4050 - accuracy: 0.0845
# Epoch 160/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.4051 - accuracy: 0.0842
# Epoch 161/200
# 39202/39202 [==============================] - 2s 40us/sample - loss: 3.4050 - accuracy: 0.0841
# Epoch 162/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4038 - accuracy: 0.0841
# Epoch 163/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.4040 - accuracy: 0.0825
# Epoch 164/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4034 - accuracy: 0.0851
# Epoch 165/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.4035 - accuracy: 0.0825
# Epoch 166/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4030 - accuracy: 0.0845
# Epoch 167/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4025 - accuracy: 0.0849
# Epoch 168/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.4024 - accuracy: 0.0839
# Epoch 169/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.4024 - accuracy: 0.0839
# Epoch 170/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4023 - accuracy: 0.0835
# Epoch 171/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4016 - accuracy: 0.0843
# Epoch 172/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.4013 - accuracy: 0.0854
# Epoch 173/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.4011 - accuracy: 0.0848
# Epoch 174/200
# 39202/39202 [==============================] - 2s 38us/sample - loss: 3.4012 - accuracy: 0.0855
# Epoch 175/200
# 39202/39202 [==============================] - 2s 48us/sample - loss: 3.4007 - accuracy: 0.0848
# Epoch 176/200
# 39202/39202 [==============================] - 2s 49us/sample - loss: 3.4002 - accuracy: 0.0854
# Epoch 177/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.4006 - accuracy: 0.0839
# Epoch 178/200
# 39202/39202 [==============================] - 2s 51us/sample - loss: 3.4005 - accuracy: 0.0868
# Epoch 179/200
# 39202/39202 [==============================] - 1s 38us/sample - loss: 3.3998 - accuracy: 0.0837
# Epoch 180/200
# 39202/39202 [==============================] - 2s 51us/sample - loss: 3.3999 - accuracy: 0.0839
# Epoch 181/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.3992 - accuracy: 0.0839
# Epoch 182/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.3992 - accuracy: 0.0841
# Epoch 183/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.3992 - accuracy: 0.0848
# Epoch 184/200
# 39202/39202 [==============================] - 2s 47us/sample - loss: 3.3987 - accuracy: 0.0844
# Epoch 185/200
# 39202/39202 [==============================] - 2s 44us/sample - loss: 3.3986 - accuracy: 0.0858
# Epoch 186/200
# 39202/39202 [==============================] - 2s 51us/sample - loss: 3.3986 - accuracy: 0.0834
# Epoch 187/200
# 39202/39202 [==============================] - 2s 50us/sample - loss: 3.3986 - accuracy: 0.0841
# Epoch 188/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.3976 - accuracy: 0.0857
# Epoch 189/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.3980 - accuracy: 0.0859
# Epoch 190/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.3982 - accuracy: 0.0857
# Epoch 191/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.3971 - accuracy: 0.0873
# Epoch 192/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.3966 - accuracy: 0.0863
# Epoch 193/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.3962 - accuracy: 0.0866
# Epoch 194/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.3966 - accuracy: 0.0859
# Epoch 195/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.3969 - accuracy: 0.0862
# Epoch 196/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.3957 - accuracy: 0.0859
# Epoch 197/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.3962 - accuracy: 0.0871
# Epoch 198/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.3960 - accuracy: 0.0853
# Epoch 199/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.3953 - accuracy: 0.0847
# Epoch 200/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.3954 - accuracy: 0.0854
