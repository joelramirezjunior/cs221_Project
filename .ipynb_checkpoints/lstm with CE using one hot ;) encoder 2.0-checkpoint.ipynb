# %%
import mido
import os
import glob
import pickle
from mido import MidiFile, MidiTrack, Message
from tensorflow.keras.layers import LSTM, Dense, Activation, Dropout, Flatten
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from tensorflow.keras import optimizers
from random import randint 
import numpy as np

# %%
def grabName(key):
    x = key.split('/')
    y = x[1]
    z = y.split('.')
    return z[0]

# %%
def geMidiFileAndTest():
    allMidiFile = 'clean_midi_songs/*.mid'
    return allMidiFile

# %%
def getNotes(allMidiFile):
        training_notes = []
        prediction_notes = dict()
        
        #getting all the notes we are training model on TO MAKE prediction
        for file in glob.glob(allMidiFile):
            individualSong = []
            midi= MidiFile(file)
            print('Loading file: ', file)
            for msg in midi:
                if not msg.is_meta and msg.type == 'note_on':
                    data = msg.bytes()
                    individualSong.append(data[1])
            # we store these to make predictions based on different songs
            prediction_notes[file] = individualSong
            # these we use to train. Stored as individual list so that the songs are 
            # not overlaped in training
            training_notes.append(individualSong)
    
        return training_notes, prediction_notes

# %%
# subsample data for training and prediction
def prepareSequences(n_prev, training_notes):

    sequences = []
    y = []

    #here we are iterating through different songs
    # this assures that none of the sequences have different songs
    for training_note in training_notes:
        for i in range(len(training_note)-n_prev):
            sequences.append(training_note[i:i+n_prev])
            y.append(training_note[i+n_prev])
    
    # save a seed to do prediction later
    # this will grab all elements up to the 301st to last
    sequence_test = sequences[-300:]
    sequences = np.asarray(sequences[:-300])
    y = y[:-300]

    return sequences, sequence_test, y

# %%
def encondeClassValues(y):
    # encode class values as integers
    encoder = LabelEncoder()
    encoder.fit(y)
    encoded_Y = encoder.transform(y)

    # convert integers to dummy variables (i.e. one hot encoded ;-) 
    dummy_y = np_utils.to_categorical(encoded_Y)
    return encoder, encoded_Y, dummy_y

# %%
# define baseline model
def baseline_model(dummy_y, n_prev):
    # create model
    model = Sequential()

    # put in this Dense 128, but it could be easily removed.
    model.add(Dense(128, input_dim=n_prev, activation='relu'))
    model.add(Dense(64, input_dim=n_prev, activation='relu'))
    model.add(Dense(len(dummy_y[0]), activation='softmax'))

    # Compile model
    # Here we use a really small learning rate becuase a larger one will not converge at all
    sgd = optimizers.SGD(lr=0.000001, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    return model

# %%
def runModel(dummy_y, sequences, nprev, numIteration ):
    model = baseline_model(dummy_y, nprev)
    model.fit(sequences, dummy_y, 8, numIteration, verbose=1)
    return model

# %%
def makePrediction(y, prediction_notes, n_prev, model):

    # these are the names for the respective file names which we created in getNotes (line 31)
    all_keys = prediction_notes.keys()

    # These are dicts inorder to predict based on different songs. This helps so that you don't 
    # have to change every single 'predicted' song in code every time. Will iterate through all.
    predictions = dict()
    class_labels = dict()
    class_labels_min = dict()
    final_labels = dict()

    # here we iterate through all songs
    for key in all_keys:
        sequenced_test_notes = []
        #differnce prediction based on different song (i.e. key)
        sequence = prediction_notes[key]
        for i in range(len(sequence)-n_prev):
            sequenced_test_notes.append(sequence[i:i+n_prev])

        # results based on song
        prediction = model.predict(np.array(sequenced_test_notes))
        class_label = np.argmax(prediction, axis=1)
        class_label_min = np.argmin(prediction, axis=1)
        labels = list(set(y))
        final_label = [labels[i] for i in class_label]
        final_labels[key] = final_label

        # saving to dictionaries
        predictions[key] = prediction
        final_labels[key] = final_label
        class_labels[key] = class_label
        class_labels_min[key] = class_label_min

    return predictions, class_labels, class_labels_min, final_labels, all_keys

# %%
def createPredictedSong(final_labels, key):
    
    mid = MidiFile()
    track = MidiTrack()
    # there is some way to moderate this to make notes less clutterd. Need To Fix.
    t = 0
    for note in final_labels[key]:
        # 147 means note_on
        # 67 is velosity
        singleNote = np.asarray([147, note, 67])
        bytes = singleNote.astype(int)
        msg = Message.from_bytes(bytes[0:3])
        t += 1 
        msg.time = t
        track.append(msg)
    # created this function to make this more legible
    key = grabName(key)
    mid.tracks.append(track)
    mid.save('created/allTrainedwith-%s-asPredicted.mid' %key)

# %%
def createSongUsedToPredict(prediction_notes, key):
    #exact same as above function, only used for predictors
    test_mid = MidiFile()
    test_track = MidiTrack()
    t = 0
    overlap = 0
    for note in prediction_notes[key]:
        # 147 means note_on
        # 67 is velosity
        note = np.asarray([147, note, 67])
        bytes = note.astype(int)
        msg = Message.from_bytes(bytes[0:3])
        t += 1 
        overlap+=1
        msg.time = t
        test_track.append(msg)
    test_mid.tracks.append(test_track)
    key = grabName(key)
    test_mid.save('predicted/predicted_song_%s.mid' %key)

# %%
# here are all the function calls
# what do you want the sequence length to be?
nprev = 4

# how many iterations do you want?
numIteration = 200

allMidiFile = geMidiFileAndTest()
training_notes, prediction_notes = getNotes(allMidiFile)
sequences, sequence_test, y = prepareSequences(nprev, training_notes)
encoder, encoded_Y, dummy_y = encondeClassValues(y)
model = runModel(dummy_y, sequences, nprev, numIteration)
predictions, class_labels, class_labels_min, final_labels, keys = makePrediction(y, prediction_notes, nprev, model)
for key in keys:
    createPredictedSong(final_labels, key)
    createSongUsedToPredict(prediction_notes, key)
# Out:
# Loading file:  clean_midi_songs/jinetera.mid
# Loading file:  clean_midi_songs/rumberaWchirino.mid
# Loading file:  clean_midi_songs/salsaPiano.mid
# Loading file:  clean_midi_songs/mujerdearenaodeloeon.mid
# Loading file:  clean_midi_songs/oPaoSalsa.mid
# Loading file:  clean_midi_songs/ahoraquien.mid
# Loading file:  clean_midi_songs/asifue.mid
# Loading file:  clean_midi_songs/lloraras.mid
# Loading file:  clean_midi_songs/MITIERRA[1].mid
# Loading file:  clean_midi_songs/abusowillieCol.mid
# Loading file:  clean_midi_songs/devorame.mid
# Loading file:  clean_midi_songs/Bamboleo.mid
# Train on 39202 samples
# Epoch 1/200
# 39202/39202 [==============================] - 2s 47us/sample - loss: 14.0377 - accuracy: 0.0242
# Epoch 2/200
# 39202/39202 [==============================] - 2s 43us/sample - loss: 10.6810 - accuracy: 0.0223
# Epoch 3/200
# 39202/39202 [==============================] - 2s 46us/sample - loss: 8.7528 - accuracy: 0.0240
# Epoch 4/200
# 39202/39202 [==============================] - 2s 48us/sample - loss: 7.6717 - accuracy: 0.0285
# Epoch 5/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 6.9861 - accuracy: 0.0328
# Epoch 6/200
# 39202/39202 [==============================] - 2s 50us/sample - loss: 6.4801 - accuracy: 0.0334
# Epoch 7/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 6.0934 - accuracy: 0.0362
# Epoch 8/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 5.7965 - accuracy: 0.0366
# Epoch 9/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 5.5616 - accuracy: 0.0375
# Epoch 10/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 5.3684 - accuracy: 0.0378
# Epoch 11/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 5.2031 - accuracy: 0.0378
# Epoch 12/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 5.0576 - accuracy: 0.0386
# Epoch 13/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 4.9295 - accuracy: 0.0396
# Epoch 14/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 4.8158 - accuracy: 0.0400
# Epoch 15/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 4.7136 - accuracy: 0.0400
# Epoch 16/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 4.6221 - accuracy: 0.0402
# Epoch 17/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 4.5385 - accuracy: 0.0406
# Epoch 18/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 4.4633 - accuracy: 0.0405
# Epoch 19/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 4.3964 - accuracy: 0.0414
# Epoch 20/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 4.3355 - accuracy: 0.0415
# Epoch 21/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 4.2813 - accuracy: 0.0414
# Epoch 22/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 4.2334 - accuracy: 0.0408
# Epoch 23/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 4.1905 - accuracy: 0.0408
# Epoch 24/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 4.1515 - accuracy: 0.0408
# Epoch 25/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 4.1164 - accuracy: 0.0410
# Epoch 26/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 4.0854 - accuracy: 0.0411
# Epoch 27/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 4.0578 - accuracy: 0.0416
# Epoch 28/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 4.0331 - accuracy: 0.0413
# Epoch 29/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 4.0110 - accuracy: 0.0414
# Epoch 30/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.9909 - accuracy: 0.0416
# Epoch 31/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.9724 - accuracy: 0.0409
# Epoch 32/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.9546 - accuracy: 0.0402
# Epoch 33/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.9377 - accuracy: 0.0400
# Epoch 34/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.9225 - accuracy: 0.0399
# Epoch 35/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.9091 - accuracy: 0.0393
# Epoch 36/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.8970 - accuracy: 0.0392
# Epoch 37/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8862 - accuracy: 0.0388
# Epoch 38/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8766 - accuracy: 0.0381
# Epoch 39/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8681 - accuracy: 0.0378
# Epoch 40/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.8608 - accuracy: 0.0383
# Epoch 41/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.8544 - accuracy: 0.0380
# Epoch 42/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8489 - accuracy: 0.0383
# Epoch 43/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.8440 - accuracy: 0.0389
# Epoch 44/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.8396 - accuracy: 0.0399
# Epoch 45/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8355 - accuracy: 0.0410
# Epoch 46/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8318 - accuracy: 0.0416
# Epoch 47/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8284 - accuracy: 0.0420
# Epoch 48/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.8253 - accuracy: 0.0421
# Epoch 49/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.8225 - accuracy: 0.0423
# Epoch 50/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.8198 - accuracy: 0.0428
# Epoch 51/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8173 - accuracy: 0.0426
# Epoch 52/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8148 - accuracy: 0.0430
# Epoch 53/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.8126 - accuracy: 0.0428
# Epoch 54/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.8105 - accuracy: 0.0431
# Epoch 55/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.8085 - accuracy: 0.0429
# Epoch 56/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.8065 - accuracy: 0.0426
# Epoch 57/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.8046 - accuracy: 0.0443
# Epoch 58/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.8029 - accuracy: 0.0442
# Epoch 59/200
# 39202/39202 [==============================] - 2s 39us/sample - loss: 3.8011 - accuracy: 0.0445
# Epoch 60/200
# 39202/39202 [==============================] - 2s 51us/sample - loss: 3.7994 - accuracy: 0.0446
# Epoch 61/200
# 39202/39202 [==============================] - 2s 53us/sample - loss: 3.7977 - accuracy: 0.0452
# Epoch 62/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.7960 - accuracy: 0.0452
# Epoch 63/200
# 39202/39202 [==============================] - 2s 52us/sample - loss: 3.7943 - accuracy: 0.0455s - loss: 3.7925
# Epoch 64/200
# 39202/39202 [==============================] - 2s 47us/sample - loss: 3.7927 - accuracy: 0.0463
# Epoch 65/200
# 39202/39202 [==============================] - 2s 47us/sample - loss: 3.7911 - accuracy: 0.0469s - loss: 3.7905 -
# Epoch 66/200
# 39202/39202 [==============================] - 2s 44us/sample - loss: 3.7895 - accuracy: 0.0468
# Epoch 67/200
# 39202/39202 [==============================] - 2s 56us/sample - loss: 3.7880 - accuracy: 0.0471
# Epoch 68/200
# 39202/39202 [==============================] - 2s 48us/sample - loss: 3.7865 - accuracy: 0.0469
# Epoch 69/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.7851 - accuracy: 0.0474
# Epoch 70/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.7836 - accuracy: 0.0475
# Epoch 71/200
# 39202/39202 [==============================] - 2s 38us/sample - loss: 3.7822 - accuracy: 0.0479
# Epoch 72/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.7809 - accuracy: 0.0479
# Epoch 73/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.7796 - accuracy: 0.0474
# Epoch 74/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.7783 - accuracy: 0.0477
# Epoch 75/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.7770 - accuracy: 0.0480
# Epoch 76/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.7757 - accuracy: 0.0472
# Epoch 77/200
# 39202/39202 [==============================] - 2s 39us/sample - loss: 3.7744 - accuracy: 0.0473
# Epoch 78/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.7732 - accuracy: 0.0466
# Epoch 79/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.7720 - accuracy: 0.0472
# Epoch 80/200
# 39202/39202 [==============================] - 2s 39us/sample - loss: 3.7708 - accuracy: 0.0471
# Epoch 81/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.7696 - accuracy: 0.0470
# Epoch 82/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.7684 - accuracy: 0.0486
# Epoch 83/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.7672 - accuracy: 0.0476
# Epoch 84/200
# 39202/39202 [==============================] - 1s 38us/sample - loss: 3.7660 - accuracy: 0.0487
# Epoch 85/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.7648 - accuracy: 0.0477
# Epoch 86/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.7636 - accuracy: 0.0492
# Epoch 87/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.7625 - accuracy: 0.0489
# Epoch 88/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.7614 - accuracy: 0.0492
# Epoch 89/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.7602 - accuracy: 0.0493
# Epoch 90/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.7591 - accuracy: 0.0495
# Epoch 91/200
# 39202/39202 [==============================] - 2s 43us/sample - loss: 3.7580 - accuracy: 0.0495
# Epoch 92/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.7568 - accuracy: 0.0491
# Epoch 93/200
# 39202/39202 [==============================] - 2s 39us/sample - loss: 3.7557 - accuracy: 0.0496
# Epoch 94/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.7546 - accuracy: 0.0497
# Epoch 95/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.7535 - accuracy: 0.0495
# Epoch 96/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.7524 - accuracy: 0.0498
# Epoch 97/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.7513 - accuracy: 0.0505
# Epoch 98/200
# 39202/39202 [==============================] - 2s 43us/sample - loss: 3.7503 - accuracy: 0.0500
# Epoch 99/200
# 39202/39202 [==============================] - 2s 39us/sample - loss: 3.7492 - accuracy: 0.0498
# Epoch 100/200
# 39202/39202 [==============================] - 2s 38us/sample - loss: 3.7481 - accuracy: 0.0506
# Epoch 101/200
# 39202/39202 [==============================] - 1s 36us/sample - loss: 3.7470 - accuracy: 0.0510
# Epoch 102/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.7459 - accuracy: 0.0507
# Epoch 103/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.7449 - accuracy: 0.0507
# Epoch 104/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.7439 - accuracy: 0.0509
# Epoch 105/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.7428 - accuracy: 0.0508
# Epoch 106/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.7418 - accuracy: 0.0509
# Epoch 107/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.7408 - accuracy: 0.0508
# Epoch 108/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.7398 - accuracy: 0.0506
# Epoch 109/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.7388 - accuracy: 0.0511
# Epoch 110/200
# 39202/39202 [==============================] - 2s 44us/sample - loss: 3.7378 - accuracy: 0.0511
# Epoch 111/200
# 39202/39202 [==============================] - 2s 46us/sample - loss: 3.7368 - accuracy: 0.0512
# Epoch 112/200
# 39202/39202 [==============================] - 2s 47us/sample - loss: 3.7359 - accuracy: 0.0511
# Epoch 113/200
# 39202/39202 [==============================] - 2s 40us/sample - loss: 3.7349 - accuracy: 0.0509
# Epoch 114/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.7339 - accuracy: 0.0508
# Epoch 115/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.7330 - accuracy: 0.0508
# Epoch 116/200
# 39202/39202 [==============================] - 1s 27us/sample - loss: 3.7320 - accuracy: 0.0509
# Epoch 117/200
# 39202/39202 [==============================] - 2s 41us/sample - loss: 3.7311 - accuracy: 0.0509
# Epoch 118/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.7301 - accuracy: 0.0511
# Epoch 119/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.7292 - accuracy: 0.0513
# Epoch 120/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.7283 - accuracy: 0.0515
# Epoch 121/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.7273 - accuracy: 0.0513
# Epoch 122/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.7264 - accuracy: 0.0515
# Epoch 123/200
# 39202/39202 [==============================] - 2s 48us/sample - loss: 3.7254 - accuracy: 0.0521
# Epoch 124/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.7245 - accuracy: 0.0525
# Epoch 125/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.7236 - accuracy: 0.0524
# Epoch 126/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.7226 - accuracy: 0.0522
# Epoch 127/200
# 39202/39202 [==============================] - 2s 43us/sample - loss: 3.7217 - accuracy: 0.0528
# Epoch 128/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.7208 - accuracy: 0.0526
# Epoch 129/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.7199 - accuracy: 0.0527
# Epoch 130/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.7189 - accuracy: 0.0530
# Epoch 131/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.7180 - accuracy: 0.0527
# Epoch 132/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.7171 - accuracy: 0.0532
# Epoch 133/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.7162 - accuracy: 0.0533
# Epoch 134/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.7153 - accuracy: 0.0534
# Epoch 135/200
# 39202/39202 [==============================] - 2s 45us/sample - loss: 3.7144 - accuracy: 0.0535
# Epoch 136/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.7135 - accuracy: 0.0537
# Epoch 137/200
# 39202/39202 [==============================] - 2s 54us/sample - loss: 3.7126 - accuracy: 0.0536
# Epoch 138/200
# 39202/39202 [==============================] - 2s 40us/sample - loss: 3.7117 - accuracy: 0.0537
# Epoch 139/200
# 39202/39202 [==============================] - 2s 52us/sample - loss: 3.7108 - accuracy: 0.0540
# Epoch 140/200
# 39202/39202 [==============================] - 2s 57us/sample - loss: 3.7099 - accuracy: 0.0540
# Epoch 141/200
# 39202/39202 [==============================] - 2s 48us/sample - loss: 3.7090 - accuracy: 0.0540
# Epoch 142/200
# 39202/39202 [==============================] - 2s 46us/sample - loss: 3.7081 - accuracy: 0.0540
# Epoch 143/200
# 39202/39202 [==============================] - 1s 38us/sample - loss: 3.7072 - accuracy: 0.0542
# Epoch 144/200
# 39202/39202 [==============================] - 1s 34us/sample - loss: 3.7063 - accuracy: 0.0540
# Epoch 145/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.7055 - accuracy: 0.0540
# Epoch 146/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.7046 - accuracy: 0.0540
# Epoch 147/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.7037 - accuracy: 0.0544
# Epoch 148/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.7028 - accuracy: 0.0540
# Epoch 149/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.7019 - accuracy: 0.0542
# Epoch 150/200
# 39202/39202 [==============================] - 1s 27us/sample - loss: 3.7011 - accuracy: 0.0543
# Epoch 151/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.7002 - accuracy: 0.0541
# Epoch 152/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6993 - accuracy: 0.0544
# Epoch 153/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6985 - accuracy: 0.0544
# Epoch 154/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6976 - accuracy: 0.0542
# Epoch 155/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6968 - accuracy: 0.0540
# Epoch 156/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6959 - accuracy: 0.0540
# Epoch 157/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6951 - accuracy: 0.0542
# Epoch 158/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6943 - accuracy: 0.0541
# Epoch 159/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6934 - accuracy: 0.0539
# Epoch 160/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6926 - accuracy: 0.0544
# Epoch 161/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6918 - accuracy: 0.0548
# Epoch 162/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6910 - accuracy: 0.0548
# Epoch 163/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6902 - accuracy: 0.0546
# Epoch 164/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6894 - accuracy: 0.0546
# Epoch 165/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.6886 - accuracy: 0.0544
# Epoch 166/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6878 - accuracy: 0.0550
# Epoch 167/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6870 - accuracy: 0.0545
# Epoch 168/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6862 - accuracy: 0.0547
# Epoch 169/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6854 - accuracy: 0.0548
# Epoch 170/200
# 39202/39202 [==============================] - 2s 49us/sample - loss: 3.6846 - accuracy: 0.0544
# Epoch 171/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.6838 - accuracy: 0.0546
# Epoch 172/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.6830 - accuracy: 0.0547
# Epoch 173/200
# 39202/39202 [==============================] - 2s 39us/sample - loss: 3.6822 - accuracy: 0.0548
# Epoch 174/200
# 39202/39202 [==============================] - 1s 35us/sample - loss: 3.6814 - accuracy: 0.0547
# Epoch 175/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.6806 - accuracy: 0.0550
# Epoch 176/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.6798 - accuracy: 0.0550
# Epoch 177/200
# 39202/39202 [==============================] - 2s 42us/sample - loss: 3.6790 - accuracy: 0.0549
# Epoch 178/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.6782 - accuracy: 0.0541
# Epoch 179/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.6774 - accuracy: 0.0552
# Epoch 180/200
# 39202/39202 [==============================] - 1s 31us/sample - loss: 3.6766 - accuracy: 0.0567
# Epoch 181/200
# 39202/39202 [==============================] - 2s 39us/sample - loss: 3.6758 - accuracy: 0.0549
# Epoch 182/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.6751 - accuracy: 0.0554
# Epoch 183/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.6743 - accuracy: 0.0555
# Epoch 184/200
# 39202/39202 [==============================] - 1s 37us/sample - loss: 3.6735 - accuracy: 0.0559
# Epoch 185/200
# 39202/39202 [==============================] - 2s 53us/sample - loss: 3.6728 - accuracy: 0.0589
# Epoch 186/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.6720 - accuracy: 0.0579
# Epoch 187/200
# 39202/39202 [==============================] - 1s 32us/sample - loss: 3.6712 - accuracy: 0.0584
# Epoch 188/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6705 - accuracy: 0.0585
# Epoch 189/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6697 - accuracy: 0.0583
# Epoch 190/200
# 39202/39202 [==============================] - 2s 56us/sample - loss: 3.6690 - accuracy: 0.0581
# Epoch 191/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.6682 - accuracy: 0.0583
# Epoch 192/200
# 39202/39202 [==============================] - 1s 33us/sample - loss: 3.6675 - accuracy: 0.0584
# Epoch 193/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.6667 - accuracy: 0.0584
# Epoch 194/200
# 39202/39202 [==============================] - 1s 30us/sample - loss: 3.6660 - accuracy: 0.0581
# Epoch 195/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6653 - accuracy: 0.0584
# Epoch 196/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6645 - accuracy: 0.0585
# Epoch 197/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6638 - accuracy: 0.0587
# Epoch 198/200
# 39202/39202 [==============================] - 1s 29us/sample - loss: 3.6630 - accuracy: 0.0590
# Epoch 199/200
# 39202/39202 [==============================] - 1s 28us/sample - loss: 3.6623 - accuracy: 0.0586
# Epoch 200/200
# 39202/39202 [==============================] - 1s 27us/sample - loss: 3.6616 - accuracy: 0.0585
